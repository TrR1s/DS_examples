# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import NullFormatter
from scipy import stats
import plotly.express as px
plt.style.use('ggplot')   
# %matplotlib inline

# %%
pl_fig = pd.read_csv("plr_fig.csv")

# %%
pl_fig.head()
# Out:
#     id  visits       res_sum     res_std    res_mean  hands_sum  hands_std  \
# 0  513     188 -29382.304651  249.247029 -156.288855    74560.0  40.662288
# 1  518     203  -1232.860863   83.450434   -6.073206    15010.0  11.791140
# 2  263     183  -1402.998446  102.886873   -7.666658    12589.0  11.584357
# 3  781     173  -2963.785871   92.512466  -17.131710    12037.0  13.357727
# 4  787     190   3968.189165  469.671462   20.885206    18868.0  16.909713
#
#    hands_mean       bets_sum    bets_std    bets_mean
# 0  396.595745  766991.775396  418.289172  4079.743486
# 1   73.940887  148780.741304  116.875056   732.910056
# 2   68.792350  124707.374972  114.755319   681.461065
# 3   69.578035  113453.527178  125.901910   655.800735
# 4   99.305263  672784.397617  602.956915  3540.970514

# %%
pl_fig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          100 non-null    int64
#  1   visits      100 non-null    int64
#  2   res_sum     100 non-null    float64
#  3   res_std     100 non-null    float64
#  4   res_mean    100 non-null    float64
#  5   hands_sum   100 non-null    float64
#  6   hands_std   100 non-null    float64
#  7   hands_mean  100 non-null    float64
#  8   bets_sum    100 non-null    float64
#  9   bets_std    100 non-null    float64
#  10  bets_mean   100 non-null    float64
# dtypes: float64(9), int64(2)
# memory usage: 8.7 KB

# %%
pl_fig.describe()
# Out:
#                id      visits       res_sum      res_std    res_mean  \
# count  100.000000  100.000000    100.000000   100.000000  100.000000
# mean   513.260000  184.970000 -10449.930671   327.551771  -56.336523
# std    259.121422   11.487767  12875.293571   368.043288   68.938606
# min    100.000000  153.000000 -50308.880114    83.450434 -281.055196
# 25%    294.750000  178.000000 -18669.367667    98.102880 -101.759495
# 50%    499.000000  185.500000  -5110.601951   227.766260  -26.898263
# 75%    751.750000  192.250000  -2270.277770   431.318260  -12.091638
# max    979.000000  214.000000  44959.808584  1542.035869  237.882585
#
#           hands_sum   hands_std  hands_mean      bets_sum     bets_std  \
# count    100.000000  100.000000  100.000000  1.000000e+02   100.000000
# mean   33246.970000   22.609862  179.761541  6.536271e+05   545.407036
# std    26894.162272   12.863385  144.740101  7.380978e+05   796.406248
# min     3676.000000    2.011570   19.449735  1.090402e+05    97.751121
# 25%    12859.500000   12.001797   68.777252  1.286204e+05   120.997507
# 50%    18356.500000   15.078229   98.976923  6.241253e+05   390.456069
# 75%    67641.000000   38.275908  387.103813  7.285011e+05   490.076786
# max    85467.000000   48.056811  423.103960  3.085954e+06  3314.350854
#
#           bets_mean
# count    100.000000
# mean    3505.285436
# std     3878.682126
# min      616.046490
# 25%      689.702170
# 50%     3427.099254
# 75%     3920.737788
# max    15840.173186

# %%
pl_fig[['res_mean','hands_mean','bets_mean', 'visits']].hist(figsize=(12,6), bins=30);

# %%
g = (
    pl_fig[['bets_mean', 'hands_mean']]
    .apply(lambda w: np.log(w + 1))
    .hist(figsize=(12,6), bins=30)
)

g;

# %%
# !pip install plotly

# %%
# px.scatter_3d(
#     pl_fig,
#     x='res_sum',
#     y='bets_mean',
#     z='visits',
#     color='visits'
# ).show(renderer='browser')

# %%
px.scatter_3d(
    pl_fig,
    x='res_sum',
    y='bets_mean',
    z='visits',
    color='visits'
).show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
pl_fig['visits_quar'] = pd.qcut(pl_fig['visits'],4,['1','2','3','4'])
pl_fig['res_sum_quar'] = pd.qcut(pl_fig['res_sum'],4,['1','2','3','4'])
pl_fig['bets_mean_quar'] = pd.qcut(pl_fig['bets_mean'],4,['1','2','3','4'])

# %%
pl_fig
# Out:
#      id  visits       res_sum     res_std    res_mean  hands_sum  hands_std  \
# 0   513     188 -29382.304651  249.247029 -156.288855    74560.0  40.662288
# 1   518     203  -1232.860863   83.450434   -6.073206    15010.0  11.791140
# 2   263     183  -1402.998446  102.886873   -7.666658    12589.0  11.584357
# 3   781     173  -2963.785871   92.512466  -17.131710    12037.0  13.357727
# 4   787     190   3968.189165  469.671462   20.885206    18868.0  16.909713
# ..  ...     ...           ...         ...         ...        ...        ...
# 95  505     178 -20859.224279  228.891984 -117.186653    68990.0  42.081865
# 96  506     187  -1969.375669   99.547638  -10.531421    12514.0  11.800434
# 97  507     197  -2456.459168   98.579910  -12.469336    13029.0  11.605027
# 98  764     180  -2283.062292   99.571682  -12.683679    12161.0  10.329657
# 99  511     163  -4096.296278  475.850423  -25.130652    17007.0  13.803716
#
#     hands_mean       bets_sum    bets_std    bets_mean visits_quar  \
# 0   396.595745  766991.775396  418.289172  4079.743486           3
# 1    73.940887  148780.741304  116.875056   732.910056           4
# 2    68.792350  124707.374972  114.755319   681.461065           2
# 3    69.578035  113453.527178  125.901910   655.800735           1
# 4    99.305263  672784.397617  602.956915  3540.970514           3
# ..         ...            ...         ...          ...         ...
# 95  387.584270  691135.258640  421.572120  3882.782352           1
# 96   66.919786  127518.244268  120.246977   681.915745           3
# 97   66.137056  129498.454951  115.345233   657.352563           4
# 98   67.561111  115081.395509   97.751121   639.341086           2
# 99  104.337423  593855.585807  482.002358  3643.285802           1
#
#    res_sum_quar bets_mean_quar
# 0             1              4
# 1             4              2
# 2             4              1
# 3             3              1
# 4             4              3
# ..          ...            ...
# 95            1              3
# 96            4              1
# 97            3              1
# 98            3              1
# 99            3              3
#
# [100 rows x 14 columns]

# %%
pl_fig['vrb']= pl_fig.visits_quar.astype(str) + pl_fig.res_sum_quar.astype(str)+pl_fig.bets_mean_quar.astype(str)

# %%
pl_fig
# Out:
#      id  visits       res_sum     res_std    res_mean  hands_sum  hands_std  \
# 0   513     188 -29382.304651  249.247029 -156.288855    74560.0  40.662288
# 1   518     203  -1232.860863   83.450434   -6.073206    15010.0  11.791140
# 2   263     183  -1402.998446  102.886873   -7.666658    12589.0  11.584357
# 3   781     173  -2963.785871   92.512466  -17.131710    12037.0  13.357727
# 4   787     190   3968.189165  469.671462   20.885206    18868.0  16.909713
# ..  ...     ...           ...         ...         ...        ...        ...
# 95  505     178 -20859.224279  228.891984 -117.186653    68990.0  42.081865
# 96  506     187  -1969.375669   99.547638  -10.531421    12514.0  11.800434
# 97  507     197  -2456.459168   98.579910  -12.469336    13029.0  11.605027
# 98  764     180  -2283.062292   99.571682  -12.683679    12161.0  10.329657
# 99  511     163  -4096.296278  475.850423  -25.130652    17007.0  13.803716
#
#     hands_mean       bets_sum    bets_std    bets_mean visits_quar  \
# 0   396.595745  766991.775396  418.289172  4079.743486           3
# 1    73.940887  148780.741304  116.875056   732.910056           4
# 2    68.792350  124707.374972  114.755319   681.461065           2
# 3    69.578035  113453.527178  125.901910   655.800735           1
# 4    99.305263  672784.397617  602.956915  3540.970514           3
# ..         ...            ...         ...          ...         ...
# 95  387.584270  691135.258640  421.572120  3882.782352           1
# 96   66.919786  127518.244268  120.246977   681.915745           3
# 97   66.137056  129498.454951  115.345233   657.352563           4
# 98   67.561111  115081.395509   97.751121   639.341086           2
# 99  104.337423  593855.585807  482.002358  3643.285802           1
#
#    res_sum_quar bets_mean_quar  vrb
# 0             1              4  314
# 1             4              2  442
# 2             4              1  241
# 3             3              1  131
# 4             4              3  343
# ..          ...            ...  ...
# 95            1              3  113
# 96            4              1  341
# 97            3              1  431
# 98            3              1  231
# 99            3              3  133
#
# [100 rows x 15 columns]

# %%
clusters = pl_fig['vrb'].value_counts()

# %%
good_cluster = clusters[clusters >=3].index.values

# %%
good_cluster
# Out:
# array(['414', '142', '123', '314', '241', '332', '431', '331', '441',
#        '124', '222', '131', '114', '313', '424', '423', '113', '232'],
#       dtype=object)

# %%
px.scatter_3d(
    pl_fig[pl_fig.vrb.isin(good_cluster)],
    x='res_sum',
    y='bets_mean',
    z='hands_sum',
    color='vrb'
).show(renderer='iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
px.scatter_3d(
    pl_fig,
    x='res_sum',
    y='res_std',
    z='hands_sum',
    color='res_mean'
# ).show(renderer='iframe')
).show(renderer='browser')
